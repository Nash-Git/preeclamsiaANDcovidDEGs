# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('preeclamsiaHypertensionGSE48424.xlsx')

# %%
df.head()
# Out:
#              ID  adj.P.Val       P.Value         t         B     logFC  \
# 0   A_23_P80062    0.00586  3.170000e-07  6.225326  6.459465  0.911071
# 1   A_32_P64990    0.00586  3.670000e-07 -6.177732  6.327744 -0.575590
# 2  A_23_P325802    0.00586  4.410000e-07  6.118760  6.164347  0.870872
# 3  A_23_P206413    0.00586  5.910000e-07 -6.024602  5.903080 -0.592237
# 4  A_32_P207243    0.00586  7.680000e-07 -5.940304  5.668819 -0.814325
#
#   Gene.symbol                                    Gene.title
# 0        TAF4  TATA-box binding protein associated factor 4
# 1         NaN                                           NaN
# 2       USP15               ubiquitin specific peptidase 15
# 3         NaN                                           NaN
# 4         NaN                                           NaN

# %%
df.shape
# Out:
# (41000, 8)

# %% [markdown]
# ### Checking and removing null values: where Gene.symbol is null

# %%
df.isna().sum()
# Out:
# ID                 0
# adj.P.Val          0
# P.Value            0
# t                  0
# B                  0
# logFC              0
# Gene.symbol    10277
# Gene.title     10277
# dtype: int64

# %%
df.dropna(inplace=True,axis=0,subset=['Gene.symbol'])

# %%
df.shape
# Out:
# (30723, 8)

# %%
df.head()
# Out:
#              ID  adj.P.Val       P.Value         t         B     logFC  \
# 0   A_23_P80062    0.00586  3.170000e-07  6.225326  6.459465  0.911071
# 2  A_23_P325802    0.00586  4.410000e-07  6.118760  6.164347  0.870872
# 5  A_23_P324718    0.00586  8.580000e-07  5.904928  5.570423  1.119439
# 6  A_23_P256526    0.00737  1.260000e-06 -5.780862  5.225014 -0.955485
# 7  A_24_P123190    0.00737  1.610000e-06  5.702846  5.007608  1.536447
#
#   Gene.symbol                                    Gene.title
# 0        TAF4  TATA-box binding protein associated factor 4
# 2       USP15               ubiquitin specific peptidase 15
# 5       SYNJ1                                synaptojanin 1
# 6       ZNF80                        zinc finger protein 80
# 7        PLD1                              phospholipase D1

# %% [markdown]
# ### Consider the rows where adj.P.Val are less than 0.05

# %%
#count rows where adj.P.Val are equal to or greater than 0.05
df.loc[df['adj.P.Val'] >= 0.05].count()
# Out:
# ID             30204
# adj.P.Val      30204
# P.Value        30204
# t              30204
# B              30204
# logFC          30204
# Gene.symbol    30204
# Gene.title     30204
# dtype: int64

# %%
#remove the rows where adj.P.Val are equal to or greater than 0.05
index_names = df[df['adj.P.Val'] >= 0.05].index
df.drop(index_names, inplace=True)

# %%
df.shape
# Out:
# (519, 8)

# %%
df.head()
# Out:
#              ID  adj.P.Val       P.Value         t         B     logFC  \
# 0   A_23_P80062    0.00586  3.170000e-07  6.225326  6.459465  0.911071
# 2  A_23_P325802    0.00586  4.410000e-07  6.118760  6.164347  0.870872
# 5  A_23_P324718    0.00586  8.580000e-07  5.904928  5.570423  1.119439
# 6  A_23_P256526    0.00737  1.260000e-06 -5.780862  5.225014 -0.955485
# 7  A_24_P123190    0.00737  1.610000e-06  5.702846  5.007608  1.536447
#
#   Gene.symbol                                    Gene.title
# 0        TAF4  TATA-box binding protein associated factor 4
# 2       USP15               ubiquitin specific peptidase 15
# 5       SYNJ1                                synaptojanin 1
# 6       ZNF80                        zinc finger protein 80
# 7        PLD1                              phospholipase D1

# %% [markdown]
# ### Find the absolute values of logFC, and take the rows where absolute values of logFC >= 1

# %%
df['absolute_logFC'] = df['logFC'].abs()

# %%
df.head()
# Out:
#              ID  adj.P.Val       P.Value         t         B     logFC  \
# 0   A_23_P80062    0.00586  3.170000e-07  6.225326  6.459465  0.911071
# 2  A_23_P325802    0.00586  4.410000e-07  6.118760  6.164347  0.870872
# 5  A_23_P324718    0.00586  8.580000e-07  5.904928  5.570423  1.119439
# 6  A_23_P256526    0.00737  1.260000e-06 -5.780862  5.225014 -0.955485
# 7  A_24_P123190    0.00737  1.610000e-06  5.702846  5.007608  1.536447
#
#   Gene.symbol                                    Gene.title  absolute_logFC
# 0        TAF4  TATA-box binding protein associated factor 4        0.911071
# 2       USP15               ubiquitin specific peptidase 15        0.870872
# 5       SYNJ1                                synaptojanin 1        1.119439
# 6       ZNF80                        zinc finger protein 80        0.955485
# 7        PLD1                              phospholipase D1        1.536447

# %%
#count the number of rows where absolute_logGC < 1
df[df['absolute_logFC'] < 1].count()
# Out:
# ID                454
# adj.P.Val         454
# P.Value           454
# t                 454
# B                 454
# logFC             454
# Gene.symbol       454
# Gene.title        454
# absolute_logFC    454
# dtype: int64

# %%
#remove the rows where the values of absolute_logFC are less than 1
index_names = df[df['absolute_logFC'] < 1].index
df.drop(index_names, inplace=True)

# %%
pd.set_option('display.max_row',None)
df
# Out:
#                ID  adj.P.Val       P.Value         t         B     logFC  \
# 5    A_23_P324718    0.00586  8.580000e-07  5.904928  5.570423  1.119439
# 7    A_24_P123190    0.00737  1.610000e-06  5.702846  5.007608  1.536447
# 26   A_24_P191790    0.00997  6.620000e-06  5.248076  3.739782  1.670550
# 31    A_23_P91390    0.01056  8.380000e-06  5.171775  3.527432  1.072994
# 38   A_23_P212061    0.01065  1.010000e-05  5.110504  3.357084  1.292596
# 49   A_24_P356592    0.01201  1.470000e-05  4.989551  3.021382  1.207501
# 55   A_24_P389608    0.01265  1.730000e-05  4.936589  2.874673  1.196129
# 66   A_23_P133174    0.01527  2.510000e-05  4.815702  2.540609  1.319197
# 72    A_24_P43391    0.01590  2.850000e-05  4.774151  2.426075  1.143486
# 79     A_23_P6849    0.01696  3.340000e-05  4.722490  2.283905  1.213366
# 81   A_23_P120345    0.01719  3.460000e-05  4.711537  2.253799  1.008526
# 91   A_23_P433753    0.01745  3.920000e-05  4.670707  2.141678  1.074396
# 98   A_24_P179175    0.01816  4.380000e-05  4.633614  2.039982  1.175172
# 109  A_23_P303155    0.01876  5.080000e-05  4.585295  1.907749  1.036671
# 120  A_23_P305060    0.01885  5.570000e-05  4.555147  1.825390  1.209118
# 133  A_23_P348257    0.01988  6.550000e-05 -4.501782  1.679898 -1.251253
# 143  A_23_P110122    0.02057  7.230000e-05  4.468897  1.590436  1.146838
# 150   A_23_P58835    0.02141  7.890000e-05  4.440194  1.512477  1.441072
# 161  A_24_P153511    0.02197  8.940000e-05  4.398751  1.400132  1.240604
# 164   A_23_P70290    0.02197  9.090000e-05  4.393137  1.384934  1.135352
# 180  A_23_P201758    0.02197  9.720000e-05  4.370877  1.324722  1.229661
# 181   A_32_P66881    0.02197  9.840000e-05  4.366880  1.313916  1.099306
# 191  A_23_P324633    0.02253  1.050000e-04  4.343651  1.251181  1.012583
# 198  A_32_P159989    0.02280  1.120000e-04 -4.324853  1.200479 -1.012997
# 205   A_23_P28485    0.02280  1.150000e-04  4.314798  1.173382  1.040471
# 221  A_24_P324886    0.02398  1.300000e-04  4.273735  1.062901  1.154613
# 228  A_23_P398073    0.02447  1.370000e-04  4.257308  1.018789  1.104476
# 231  A_23_P217428    0.02474  1.400000e-04  4.249278  0.997242  1.121974
# 234  A_24_P252043    0.02497  1.430000e-04  4.241397  0.976105  1.267742
# 242  A_23_P145657    0.02528  1.500000e-04 -4.226515  0.936227 -1.002613
# 251  A_23_P155755    0.02621  1.620000e-04  4.200559  0.866768  1.194860
# 268  A_23_P100022    0.02685  1.770000e-04 -4.169680  0.784305 -1.143446
# 278  A_24_P250922    0.02692  1.830000e-04  4.159033  0.755914  1.026642
# 290  A_32_P225355    0.02722  1.930000e-04  4.141102  0.708152  1.623131
# 304  A_24_P256830    0.02828  2.100000e-04  4.112440  0.631939  1.163572
# 305   A_32_P22571    0.02831  2.120000e-04  4.109892  0.625173  1.207440
# 315  A_23_P121564    0.02889  2.230000e-04  4.093176  0.580812  1.168825
# 327  A_24_P922261    0.02984  2.390000e-04 -4.069737  0.518707 -1.295070
# 335   A_23_P22398    0.03107  2.550000e-04 -4.047816  0.460732 -1.532881
# 337  A_23_P154130    0.03134  2.580000e-04  4.042880  0.447692  1.054781
# 340   A_23_P20363    0.03141  2.610000e-04 -4.038985  0.437406 -1.045464
# 352  A_23_P433204    0.03245  2.790000e-04  4.016314  0.377601  1.105105
# 354  A_23_P391443    0.03261  2.820000e-04  4.012768  0.368256  1.187588
# 355   A_23_P23616    0.03278  2.850000e-04 -4.009995  0.360951 -1.180219
# 365  A_23_P117662    0.03377  3.020000e-04  3.989707  0.307560  1.700695
# 368  A_24_P180424    0.03377  3.040000e-04  3.987473  0.301687  1.012850
# 371  A_24_P541576    0.03390  3.080000e-04  3.983609  0.291530  1.520798
# 383  A_23_P413303    0.03423  3.210000e-04  3.968650  0.252245  1.206995
# 442  A_24_P374741    0.03551  3.840000e-04 -3.908070  0.093685 -1.204181
# 461  A_23_P163079    0.03624  4.080000e-04  3.886753  0.038102  1.016038
# 464  A_24_P131622    0.03638  4.130000e-04 -3.883192  0.028830 -1.202623
# 468  A_24_P931503    0.03657  4.180000e-04  3.878406  0.016369  1.624736
# 474  A_24_P256380    0.03680  4.260000e-04  3.871821 -0.000762  1.068795
# 488  A_24_P285522    0.03742  4.460000e-04  3.856183 -0.041409  1.117554
# 514  A_24_P292710    0.03949  4.960000e-04  3.819692 -0.136006  1.047258
# 520   A_23_P55639    0.03968  5.050000e-04  3.813475 -0.152088  1.062256
# 526  A_24_P174341    0.03968  5.120000e-04  3.808664 -0.164525  1.231144
# 540   A_32_P10116    0.03999  5.290000e-04 -3.797393 -0.193642 -1.047572
# 551   A_23_P52499    0.04031  5.440000e-04  3.787850 -0.218267  1.147306
# 552   A_23_P10081    0.04031  5.450000e-04  3.787542 -0.219062  1.322017
# 554  A_23_P212665    0.04068  5.510000e-04  3.783633 -0.229139  1.332842
# 573   A_24_P80532    0.04333  6.070000e-04  3.750126 -0.315368  1.211515
# 582  A_24_P933492    0.04378  6.240000e-04 -3.740537 -0.339989 -1.056589
# 589  A_24_P108863    0.04400  6.330000e-04  3.735245 -0.353566  1.211327
# 644  A_23_P170679    0.04868  7.670000e-04  3.668415 -0.524332  1.154750
#
#        Gene.symbol                                         Gene.title  \
# 5            SYNJ1                                     synaptojanin 1
# 7             PLD1                                   phospholipase D1
# 26          TMEM33                           transmembrane protein 33
# 31            THBD                                     thrombomodulin
# 38             MME                     membrane metallo-endopeptidase
# 49         PRKAR1A  protein kinase cAMP-dependent type I regulator...
# 55         PROSER2                          proline and serine rich 2
# 66         TMEM165                          transmembrane protein 165
# 72         TMEM165                          transmembrane protein 165
# 79            CCR1                     C-C motif chemokine receptor 1
# 81           PELI1              pellino E3 ubiquitin protein ligase 1
# 91         PRKAR1A  protein kinase cAMP-dependent type I regulator...
# 98            PHC3                             polyhomeotic homolog 3
# 109        TMEM87B                          transmembrane protein 87B
# 120          NAMPT             nicotinamide phosphoribosyltransferase
# 133          NUAK1                               NUAK family kinase 1
# 143          CCNG2                                          cyclin G2
# 150          F2RL1                        F2R like trypsin receptor 1
# 161         OSBPL8                   oxysterol binding protein like 8
# 164        TMEM30A                          transmembrane protein 30A
# 180           CD46                                      CD46 molecule
# 181           TLR4                               toll like receptor 4
# 191        C9orf72                 chromosome 9 open reading frame 72
# 198         NKAPP1               NFKB activating protein pseudogene 1
# 205            GCA                                         grancalcin
# 221          DOCK4                         dedicator of cytokinesis 4
# 228          PPM1B        protein phosphatase, Mg2+/Mn2+ dependent 1B
# 231        ARHGAP6                    Rho GTPase activating protein 6
# 234         PTP4A1    protein tyrosine phosphatase type IVA, member 1
# 242          STAG3                                  stromal antigen 3
# 251          CXCL6                     C-X-C motif chemokine ligand 6
# 268           SV2B                   synaptic vesicle glycoprotein 2B
# 278          PTGS2              prostaglandin-endoperoxide synthase 2
# 290          CPEB2  cytoplasmic polyadenylation element binding pr...
# 304          EXOC5                        exocyst complex component 5
# 305   LOC100288675                       uncharacterized LOC100288675
# 315        GUCY1B3           guanylate cyclase 1 soluble subunit beta
# 327         SRGAP1          SLIT-ROBO Rho GTPase activating protein 1
# 335        MACROD2                          MACRO domain containing 2
# 337         MAP4K3  mitogen-activated protein kinase kinase kinase...
# 340        ZC2HC1A                zinc finger C2HC-type containing 1A
# 352          RHOT1                       ras homolog family member T1
# 354          PPM1H        protein phosphatase, Mg2+/Mn2+ dependent 1H
# 355        PLEKHN1           pleckstrin homology domain containing N1
# 365            HDC                            histidine decarboxylase
# 368        TMEM30A                          transmembrane protein 30A
# 371      LOC389831                          uncharacterized LOC389831
# 383  DKFZP434I0714              uncharacterized protein DKFZP434I0714
# 442         FRMD4A                          FERM domain containing 4A
# 461           GCH1                               GTP cyclohydrolase 1
# 464        FAM107A       family with sequence similarity 107 member A
# 468           PHIP     pleckstrin homology domain interacting protein
# 474            WLS              wntless Wnt ligand secretion mediator
# 488         MAP4K3  mitogen-activated protein kinase kinase kinase...
# 514          GSKIP                          GSK3B interacting protein
# 520         RPRD1A  regulation of nuclear pre-mRNA domain containi...
# 526          CCNT2                                          cyclin T2
# 540        TMEM245                          transmembrane protein 245
# 551        SLC18A2                 solute carrier family 18 member A2
# 552         ARL13B            ADP ribosylation factor like GTPase 13B
# 554          ABCC5          ATP binding cassette subfamily C member 5
# 573          CCNG2                                          cyclin G2
# 582        ZDHHC21                zinc finger DHHC-type containing 21
# 589          SCML1             sex comb on midleg-like 1 (Drosophila)
# 644         COL4A3                     collagen type IV alpha 3 chain
#
#      absolute_logFC
# 5          1.119439
# 7          1.536447
# 26         1.670550
# 31         1.072994
# 38         1.292596
# 49         1.207501
# 55         1.196129
# 66         1.319197
# 72         1.143486
# 79         1.213366
# 81         1.008526
# 91         1.074396
# 98         1.175172
# 109        1.036671
# 120        1.209118
# 133        1.251253
# 143        1.146838
# 150        1.441072
# 161        1.240604
# 164        1.135352
# 180        1.229661
# 181        1.099306
# 191        1.012583
# 198        1.012997
# 205        1.040471
# 221        1.154613
# 228        1.104476
# 231        1.121974
# 234        1.267742
# 242        1.002613
# 251        1.194860
# 268        1.143446
# 278        1.026642
# 290        1.623131
# 304        1.163572
# 305        1.207440
# 315        1.168825
# 327        1.295070
# 335        1.532881
# 337        1.054781
# 340        1.045464
# 352        1.105105
# 354        1.187588
# 355        1.180219
# 365        1.700695
# 368        1.012850
# 371        1.520798
# 383        1.206995
# 442        1.204181
# 461        1.016038
# 464        1.202623
# 468        1.624736
# 474        1.068795
# 488        1.117554
# 514        1.047258
# 520        1.062256
# 526        1.231144
# 540        1.047572
# 551        1.147306
# 552        1.322017
# 554        1.332842
# 573        1.211515
# 582        1.056589
# 589        1.211327
# 644        1.154750

# %%
df.shape
# Out:
# (65, 9)

# %% [markdown]
# ### Differentially Expressed Genes

# %%
#number of down regulatd genes
df.loc[df['logFC'] < 0].count()
# Out:
# ID                12
# adj.P.Val         12
# P.Value           12
# t                 12
# B                 12
# logFC             12
# Gene.symbol       12
# Gene.title        12
# absolute_logFC    12
# dtype: int64

# %%
#number of up regulated genges
df.loc[df['logFC'] > 0].count()
# Out:
# ID                53
# adj.P.Val         53
# P.Value           53
# t                 53
# B                 53
# logFC             53
# Gene.symbol       53
# Gene.title        53
# absolute_logFC    53
# dtype: int64

# %%
df_downRegulated = df.loc[df['logFC'] < 0]

# %%
df_upRegulated = df.loc[df['logFC'] > 0]

# %%
df_downRegulated.head()
# Out:
#                ID  adj.P.Val   P.Value         t         B     logFC  \
# 133  A_23_P348257    0.01988  0.000066 -4.501782  1.679898 -1.251253
# 198  A_32_P159989    0.02280  0.000112 -4.324853  1.200479 -1.012997
# 242  A_23_P145657    0.02528  0.000150 -4.226515  0.936227 -1.002613
# 268  A_23_P100022    0.02685  0.000177 -4.169680  0.784305 -1.143446
# 327  A_24_P922261    0.02984  0.000239 -4.069737  0.518707 -1.295070
#
#     Gene.symbol                                 Gene.title  absolute_logFC
# 133       NUAK1                       NUAK family kinase 1        1.251253
# 198      NKAPP1       NFKB activating protein pseudogene 1        1.012997
# 242       STAG3                          stromal antigen 3        1.002613
# 268        SV2B           synaptic vesicle glycoprotein 2B        1.143446
# 327      SRGAP1  SLIT-ROBO Rho GTPase activating protein 1        1.295070

# %%
df_upRegulated.head()
# Out:
#               ID  adj.P.Val       P.Value         t         B     logFC  \
# 5   A_23_P324718    0.00586  8.580000e-07  5.904928  5.570423  1.119439
# 7   A_24_P123190    0.00737  1.610000e-06  5.702846  5.007608  1.536447
# 26  A_24_P191790    0.00997  6.620000e-06  5.248076  3.739782  1.670550
# 31   A_23_P91390    0.01056  8.380000e-06  5.171775  3.527432  1.072994
# 38  A_23_P212061    0.01065  1.010000e-05  5.110504  3.357084  1.292596
#
#    Gene.symbol                      Gene.title  absolute_logFC
# 5        SYNJ1                  synaptojanin 1        1.119439
# 7         PLD1                phospholipase D1        1.536447
# 26      TMEM33        transmembrane protein 33        1.670550
# 31        THBD                  thrombomodulin        1.072994
# 38         MME  membrane metallo-endopeptidase        1.292596

# %%
df_downRegulated.reset_index(inplace=True)

# %%
df_upRegulated.reset_index(inplace=True)

# %%
df_downRegulated.head()
# Out:
#    index            ID  adj.P.Val   P.Value         t         B     logFC  \
# 0    133  A_23_P348257    0.01988  0.000066 -4.501782  1.679898 -1.251253
# 1    198  A_32_P159989    0.02280  0.000112 -4.324853  1.200479 -1.012997
# 2    242  A_23_P145657    0.02528  0.000150 -4.226515  0.936227 -1.002613
# 3    268  A_23_P100022    0.02685  0.000177 -4.169680  0.784305 -1.143446
# 4    327  A_24_P922261    0.02984  0.000239 -4.069737  0.518707 -1.295070
#
#   Gene.symbol                                 Gene.title  absolute_logFC
# 0       NUAK1                       NUAK family kinase 1        1.251253
# 1      NKAPP1       NFKB activating protein pseudogene 1        1.012997
# 2       STAG3                          stromal antigen 3        1.002613
# 3        SV2B           synaptic vesicle glycoprotein 2B        1.143446
# 4      SRGAP1  SLIT-ROBO Rho GTPase activating protein 1        1.295070

# %%
df_downRegulated.drop(['index'],axis=1,inplace=True)

# %%
df_upRegulated.head()
# Out:
#    index            ID  adj.P.Val       P.Value         t         B     logFC  \
# 0      5  A_23_P324718    0.00586  8.580000e-07  5.904928  5.570423  1.119439
# 1      7  A_24_P123190    0.00737  1.610000e-06  5.702846  5.007608  1.536447
# 2     26  A_24_P191790    0.00997  6.620000e-06  5.248076  3.739782  1.670550
# 3     31   A_23_P91390    0.01056  8.380000e-06  5.171775  3.527432  1.072994
# 4     38  A_23_P212061    0.01065  1.010000e-05  5.110504  3.357084  1.292596
#
#   Gene.symbol                      Gene.title  absolute_logFC
# 0       SYNJ1                  synaptojanin 1        1.119439
# 1        PLD1                phospholipase D1        1.536447
# 2      TMEM33        transmembrane protein 33        1.670550
# 3        THBD                  thrombomodulin        1.072994
# 4         MME  membrane metallo-endopeptidase        1.292596

# %%
df_upRegulated.drop(['index'],axis=1,inplace=True)

# %%
df_upRegulated.head()
# Out:
#              ID  adj.P.Val       P.Value         t         B     logFC  \
# 0  A_23_P324718    0.00586  8.580000e-07  5.904928  5.570423  1.119439
# 1  A_24_P123190    0.00737  1.610000e-06  5.702846  5.007608  1.536447
# 2  A_24_P191790    0.00997  6.620000e-06  5.248076  3.739782  1.670550
# 3   A_23_P91390    0.01056  8.380000e-06  5.171775  3.527432  1.072994
# 4  A_23_P212061    0.01065  1.010000e-05  5.110504  3.357084  1.292596
#
#   Gene.symbol                      Gene.title  absolute_logFC
# 0       SYNJ1                  synaptojanin 1        1.119439
# 1        PLD1                phospholipase D1        1.536447
# 2      TMEM33        transmembrane protein 33        1.670550
# 3        THBD                  thrombomodulin        1.072994
# 4         MME  membrane metallo-endopeptidase        1.292596

# %%
writer = pd.ExcelWriter('preeclamsiaGSE48424DEG.xlsx',engine='xlsxwriter')

# %%
df_downRegulated.to_excel(writer,sheet_name='downRegulated')

# %%
df_upRegulated.to_excel(writer,sheet_name='upRegulated')

# %%
writer.save()
writer.close()
